# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
killings_data = pd.read_csv('./data/killings.csv', index_col=0)
killings_data.head()
# Out:
#   State   total_pop  black_pop  hispanic_pop  % Victims Black  Disparity  \
# 0    AL   4864680.0  1285737.0      203146.0         0.384058   0.119758
# 1    AK    738516.0    22817.0       51186.0         0.100000   0.069104
# 2    AZ   6946685.0   286614.0     2163312.0         0.090909   0.049650
# 3    AR   2990671.0   458536.0      219052.0         0.298077   0.144755
# 4    CA  39148760.0  2164519.0    15221577.0         0.158609   0.103319
#
#    black_killings  hispanic_killings  total_killings  black_rate  \
# 0            53.0                NaN           138.0    5.888785
# 1             4.0                1.0            40.0   25.043983
# 2            31.0              115.0           341.0   15.451344
# 3            31.0                3.0           104.0    9.658067
# 4           187.0              487.0          1179.0   12.341904
#
#    hispanic_rate  white_rate  total_rate  Disparity in Rate  \
# 0       0.000000    3.306951    4.052535           1.453111
# ...
